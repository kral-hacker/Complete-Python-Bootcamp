# %% [markdown]
# Tuples - ordered, immutable

# %%
t = tuple([1,2,3])
print(t)
# Out:
# (1, 2, 3)

# %%
t = (1,3,4,5)
print(t)
# Out:
# (1, 3, 4, 5)

# %%
# t[1] = "Ananay" #IMMUTABLE

# %%
s = {1,2,23,3,4,5,5}
print(type(s))
# Out:
# <class 'set'>

# %%
d = {"name":"Ananay", "age":12}
print(type(d))
print(d["name"])
# Out:
# <class 'dict'>
# Ananay
